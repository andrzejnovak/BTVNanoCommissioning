# %%
import numpy as np
from coffea.util import load

# %%
output = load("/work/mmarcheg/BTVNanoCommissioning/histograms/RunIISummer20UL18_FIXED_SV.coffea")
[histname for histname in output.keys() if 'logsv1mass' in histname]
# Out:
# ['sv_logsv1mass_basic',
#  'sv_logsv1mass_msd100tau06',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwp',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwp',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwpPt-400to600',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwpPt-400to600',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwpPt-600to800',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwpPt-600to800',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwpPt-800toInf',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwpPt-800toInf',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwpPt-600toInf',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwpPt-600toInf',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passMwp',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failMwp',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passMwpPt-400to600',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failMwpPt-400to600',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passMwpPt-600to800',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failMwpPt-600to800',
# ...

# %%
output = np.load("/work/mmarcheg/BTVNanoCommissioning/histograms/RunIISummer20UL18_FIXED_SV.pkl", allow_pickle=True)
output2 = np.load("/work/mmarcheg/BTVNanoCommissioning/histograms/RunIISummer20UL18_FIXED_SV_scaling.pkl", allow_pickle=True)

# %%
[histname for histname in output.keys() if 'logsv1mass' in histname]
# Out:
# ['sv_logsv1mass_msd100tau06btagDDBvLV2passLwp_QCD_l',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwp_QCD_b_bb',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwp_QCD_c_cc',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwp_BtagMu',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwp_QCD_l',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwp_QCD_b_bb',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwp_QCD_c_cc',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwp_BtagMu',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwpPt-400to600_QCD_l',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwpPt-400to600_QCD_b_bb',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwpPt-400to600_QCD_c_cc',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2passLwpPt-400to600_BtagMu',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwpPt-400to600_QCD_l',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwpPt-400to600_QCD_b_bb',
#  'sv_logsv1mass_msd100tau06btagDDBvLV2failLwpPt-400to600_QCD_c_cc',
# ...

# %%
output['sv_logsv1mass_msd100tau06btagDDBvLV2passMwp_QCD_b_bb']
# Out:
# [array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.11460679e+00, 1.51502888e+00,
#         3.77429850e+00, 1.43417650e+02, 5.84261840e+02, 6.58705262e+02,
#         7.38681048e+02, 8.78960917e+02, 9.97351757e+02, 1.07580918e+03,
#         1.28136635e+03, 1.25329894e+03, 1.35268058e+03, 1.08118877e+03,
#         8.80019553e+02, 6.36204632e+02, 3.01328922e+02, 9.72361393e+01,
#         1.14677086e+01, 2.13123678e+00, 7.19569710e-01, 2.07864778e+00,
#         2.62923452e-01, 6.19562607e-01, 6.31883465e-02, 7.43251211e-02,
#         2.02791279e-01, 1.62158043e-02, 2.26977762e-02, 5.85220936e-02]),
#  array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.22305599e+00, 1.18790676e+00,
# ...

# %%
output2['sv_logsv1mass_msd100tau06btagDDBvLV2passMwp_QCD_b_bb']
# Out:
# [array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.82988584e-06, 2.48727168e-06,
#         6.19638732e-06, 2.35453372e-04, 9.59201468e-04, 1.08141763e-03,
#         1.21271645e-03, 1.44301843e-03, 1.63738448e-03, 1.76619056e-03,
#         2.10366037e-03, 2.05758120e-03, 2.22073925e-03, 1.77502240e-03,
#         1.44475642e-03, 1.04447762e-03, 4.94701389e-04, 1.59635699e-04,
#         1.88269062e-05, 3.49892002e-06, 1.18134075e-06, 3.41258296e-06,
#         4.31649894e-07, 1.01715587e-06, 1.03738342e-07, 1.22021943e-07,
#         3.32928970e-07, 2.66220078e-08, 3.72636698e-08, 9.60776046e-08]),
#  array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 3.29648392e-12, 3.20174677e-12,
# ...
